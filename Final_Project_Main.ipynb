# %% [markdown]
# <a href="https://colab.research.google.com/github/will-mccormack/CS-M148-Proj/blob/main/Final_Project_Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install scikit-lego
# %pip install -U kaleido
# %pip install plotly
# %pip install plotly --upgrade
# Out:
# Collecting scikit-lego
#   Downloading scikit_lego-0.9.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: narwhals>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-lego) (2.12.0)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from scikit-lego) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-lego) (1.6.1)
# Collecting sklearn-compat>=0.1.3 (from scikit-lego)
#   Downloading sklearn_compat-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->scikit-lego) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->scikit-lego) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->scikit-lego) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->scikit-lego) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->scikit-lego) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->scikit-lego) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->scikit-lego) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->scikit-lego) (1.17.0)
# Downloading scikit_lego-0.9.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 4.1 MB/s eta 0:00:00
# Downloading sklearn_compat-0.1.4-py3-none-any.whl (19 kB)
# Installing collected packages: sklearn-compat, scikit-lego
# Successfully installed scikit-lego-0.9.6 sklearn-compat-0.1.4
# Collecting kaleido
#   Downloading kaleido-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting choreographer>=1.1.1 (from kaleido)
#   Downloading choreographer-1.2.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting logistro>=1.0.8 (from kaleido)
#   Downloading logistro-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from kaleido) (3.11.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaleido) (25.0)
# Collecting pytest-timeout>=2.4.0 (from kaleido)
#   Downloading pytest_timeout-2.4.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.1.1->kaleido) (3.20.2)
# Requirement already satisfied: pytest>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from pytest-timeout>=2.4.0->kaleido) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.19.2)
# Downloading kaleido-1.2.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 3.3 MB/s eta 0:00:00
# Downloading choreographer-1.2.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.0 MB/s eta 0:00:00
# Downloading logistro-2.0.1-py3-none-any.whl (8.6 kB)
# Downloading pytest_timeout-2.4.0-py3-none-any.whl (14 kB)
# Installing collected packages: logistro, pytest-timeout, choreographer, kaleido
# Successfully installed choreographer-1.2.1 kaleido-1.2.0 logistro-2.0.1 pytest-timeout-2.4.0
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 71.9 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed plotly-6.5.0

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import time
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
import plotly.io as pio
pio.get_chrome()
pio.renderers.default = 'png'
from itertools import product
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
get_ipython().system('sudo apt update && sudo apt-get install libnss3 libatk-bridge2.0-0 libcups2 libxcomposite1 libxdamage1 libxfixes3 libxrandr2 libgbm1 libxkbcommon0 libpango-1.0-0 libcairo2 libasound2')
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 https://cli.github.com/packages stable InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,196 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,286 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,841 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,066 kB]
# Get:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,563 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,506 kB]
# Hit:16 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:17 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,281 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,901 kB]
# Fetched 37.8 MB in 3s (14.4 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 65 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libnss3 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# The following additional packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libxtst6 session-migration
# Suggested packages:
#   cups-common
# The following NEW packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libatk-bridge2.0-0 libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libxcomposite1 libxtst6 session-migration
# The following packages will be upgraded:
#   libcups2
# 1 upgraded, 9 newly installed, 0 to remove and 64 not upgraded.
# Need to get 582 kB of archives.
# After this operation, 1,497 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcups2 amd64 2.4.1op1-1ubuntu4.15 [264 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Fetched 582 kB in 1s (599 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 10.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libatspi2.0-0:amd64.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../0-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../1-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../2-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../3-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../4-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../5-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../6-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../7-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Preparing to unpack .../8-libcups2_2.4.1op1-1ubuntu4.15_amd64.deb ...
# Unpacking libcups2:amd64 (2.4.1op1-1ubuntu4.15) over (2.4.1op1-1ubuntu4.12) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../9-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libcups2:amd64 (2.4.1op1-1ubuntu4.15) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.6) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up at-spi2-core (2.44.0-3) ...

# %%
raw_data = pd.read_csv("https://huggingface.co/datasets/maharshipandya/spotify-tracks-dataset/resolve/main/dataset.csv")

# %% [markdown]
# Read in the data

# %% [markdown]
# #EDA

# %% [markdown]
# Before splitting, check for malformed data.

# %%
print(raw_data.columns)
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %% [markdown]
# First, lets check for missing values in our dataset.

# %%
missing_values = raw_data.isnull().sum()

missing_percentage = (missing_values / len(raw_data)) * 100

missing_info = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})

display(missing_info)
# Out:
#                   Missing Values  Percentage
# Unnamed: 0                     0    0.000000
# track_id                       0    0.000000
# artists                        1    0.000877
# album_name                     1    0.000877
# track_name                     1    0.000877
# popularity                     0    0.000000
# duration_ms                    0    0.000000
# explicit                       0    0.000000
# danceability                   0    0.000000
# energy                         0    0.000000
# key                            0    0.000000
# loudness                       0    0.000000
# mode                           0    0.000000
# speechiness                    0    0.000000
# acousticness                   0    0.000000
# instrumentalness               0    0.000000
# liveness                       0    0.000000
# valence                        0    0.000000
# tempo                          0    0.000000
# time_signature                 0    0.000000
# track_genre                    0    0.000000

# %%
missing_rows = raw_data[raw_data.isnull().any(axis=1)]

display(missing_rows)
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 65900           0            0     False         0.501   0.583  ...     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre
# 65900  138.391               4        k-pop
#
# [1 rows x 21 columns]

# %% [markdown]
# We see that only one entry has NaN values, for artist, album_name, and track_name. Given that it is such a small number of rows compared to the vast dataset, we can confidently remove this row / not worry about imputing it because hte overal shape of our data will basically remain the same with or without this single row.

# %%
cleaned_data = raw_data.dropna()

drop_columns = ['track_id', 'Unnamed: 0']
cleaned_data = cleaned_data.drop(columns=drop_columns)

display(cleaned_data.head(5))
# Out:
#                   artists                                         album_name  \
# 0             Gen Hoshino                                             Comedy
# 1            Ben Woodward                                   Ghost (Acoustic)
# 2  Ingrid Michaelson;ZAYN                                     To Begin Again
# 3            Kina Grannis  Crazy Rich Asians (Original Motion Picture Sou...
# 4        Chord Overstreet                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %% [markdown]
# Now check for NA rows again to ensure our dropping worked

# %%
clean_missing_values = cleaned_data.isnull().sum()

clean_missing_values

clean_missing_percentage = (clean_missing_values / len(raw_data)) * 100

clean_missing_info = pd.DataFrame({'Missing Values': clean_missing_values, 'Percentage': clean_missing_percentage})

display(clean_missing_info)
# Out:
#                   Missing Values  Percentage
# artists                        0         0.0
# album_name                     0         0.0
# track_name                     0         0.0
# popularity                     0         0.0
# duration_ms                    0         0.0
# explicit                       0         0.0
# danceability                   0         0.0
# energy                         0         0.0
# key                            0         0.0
# loudness                       0         0.0
# mode                           0         0.0
# speechiness                    0         0.0
# acousticness                   0         0.0
# instrumentalness               0         0.0
# liveness                       0         0.0
# valence                        0         0.0
# tempo                          0         0.0
# time_signature                 0         0.0
# track_genre                    0         0.0

# %% [markdown]
# NA's removed, now we can split the data and do further EDA to see what preprocessing we need to do. First we can split the data set though to avoid data leak

# %%
train, test_and_validate = train_test_split(raw_data, test_size=0.4, random_state=42)
test, validate = train_test_split(test_and_validate, test_size=0.5, random_state=42)

# %% [markdown]
# The first thing we want to check is genre, as that seems like it could have many outliers/categories we wouldn't want to consider (i.e. podcasts, which are popular on spotify, may be counted in this dataset and we aren't concerned with these, so we would want to check). Speechiness would be a good metric to use to check for such things, so lets inspect the top most speechy songs

# %%
cleaned_data.nlargest(10, "speechiness")
# Out:
#                artists              album_name             track_name  \
# 18152      Tenacious D         Post-Apocalypto           turd whistle
# 18504         Tom Papa              Human Mule         The Real World
# 18530    Patton Oswalt    Talking for Clapping  Less and Less Radical
# 18137      Dan Cummins  Get Outta Here; Devil!  Get Rid of That Joke!
# 18227    Patton Oswalt    Talking for Clapping      Parents and Pills
# 18432  Robert Schimmel         Life Since Then           Chemotherapy
# 18663         Tom Papa              Human Mule     The Human Contract
# 18666         Tom Papa              Human Mule        Angry Young Men
# 18674         Tom Papa              Human Mule            Morning Tom
# 18067  Robert Schimmel         Life Since Then   Non Hogkins Lymphoma
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 18152          26        39426      True         0.630   0.249    4   -14.952
# 18504          22        68758     False         0.537   0.548    5   -15.100
# 18530          23       207619      True         0.650   0.461    7   -18.317
# 18137          25       191399      True         0.604   0.619    5   -13.426
# 18227          25       202358      True         0.552   0.431   10   -18.837
# 18432          22       132520      True         0.599   0.369    6   -20.816
# 18663          21       339521     False         0.617   0.592    2   -13.854
# 18666          21       136820     False         0.587   0.558   11   -14.645
# 18674          21       213995     False         0.526   0.667    6   -15.417
# 18067          28        68520      True         0.689   0.332    2   -19.407
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 18152     1        0.965         0.353               0.0     0.193    0.739
# 18504     0        0.963         0.736               0.0     0.745    0.730
# 18530     1        0.963         0.848               0.0     0.732    0.365
# 18137     1        0.962         0.682               0.0     0.860    0.562
# 18227     1        0.962         0.872               0.0     0.674    0.448
# 18432     1        0.962         0.921               0.0     0.696    0.494
# 18663     1        0.962         0.721               0.0     0.752    0.465
# 18666     0        0.962         0.795               0.0     0.807    0.559
# 18674     1        0.962         0.772               0.0     0.751    0.259
# 18067     1        0.961         0.873               0.0     0.660    0.701
#
#          tempo  time_signature track_genre
# 18152  172.243               3      comedy
# 18504  179.403               3      comedy
# 18530   50.324               4      comedy
# 18137   88.668               3      comedy
# 18227   78.361               4      comedy
# 18432   83.026               5      comedy
# 18663   90.721               4      comedy
# 18666   88.127               4      comedy
# 18674  171.074               4      comedy
# 18067   80.739               4      comedy

# %% [markdown]
# Checking the found entries, we see that these indeed are comedy shows. We want to check to see if all entries with the genre "comedy" are talk shows, because if they are we can simply remove all entries labeled comedy. Lets check the lowest speechiness comedies to see if they are actual songs, or just talking

# %%
lowest_speechy_comedies = train[train['track_genre'] == 'comedy'].nsmallest(10, "speechiness")
lowest_speechy_comedies
# Out:
#        Unnamed: 0                track_id                            artists  \
# 18826       18826  6He7HGAK721bVRUv3l6hwc                "Weird Al" Yankovic
# 18526       18526  1yk9QG4uOwZqJXM4XYA0gU                      Stephen Lynch
# 18606       18606  7u9TVTUA8uMjoZzTFThl4u                      Stephen Lynch
# 18524       18524  4hWu7G0yGOyVgZdoMcUsYe  Steve Martin;Steep Canyon Rangers
# 18379       18379  12ppMTD57vkLTeQROr1XD6                      Stephen Lynch
# 18446       18446  7uChwK0FIUOdpu8c2AFsOx         Steve Martin;Edie Brickell
# 18651       18651  0CaWTRBQ2MShWD7remjUfI                         Jon Lajoie
# 18935       18935  526mDk6dMvJqgtMpsEy8PP                        Tim Minchin
# 18895       18895  5FBvGDfcEshfwMMTwR1kgm           Richard Pryor;Lena Horne
# 18401       18401  3USOTQdPtZlgVurwaqsdI5                        Tenacious D
#
#                    album_name                   track_name  popularity  \
# 18826             Polka Party          Good Enough for Now          22
# 18526    A Little Bit Special                HermAphrodite          23
# 18606            My Old Heart                 My Old Heart          22
# 18524         Rare Bird Alert  More Bad Weather On The Way          22
# 18379    A Little Bit Special                       Gerbil          24
# 18446   Love Has Come For You            Sun's Gonna Shine          23
# 18651  You Want Some of This?                 High as F%#K          38
# 18935        Ready For This ?        White Wine In The Sun          24
# 18895                 The Wiz        The Good Witch Glinda          21
# 18401             Tenacious D              Fuck Her Gently          59
#
#        duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 18826       183333     False         0.661   0.412  ...   -13.015     1
# 18526       169213      True         0.483   0.424  ...    -7.724     1
# 18606       314480      True         0.668   0.203  ...   -10.825     1
# 18524       211960     False         0.549   0.545  ...    -9.162     1
# 18379       184413      True         0.640   0.343  ...    -8.999     0
# 18446       185346     False         0.355   0.368  ...    -9.494     1
# 18651       174986      True         0.517   0.424  ...   -11.046     1
# 18935       432218     False         0.402   0.248  ...   -14.311     1
# 18895        69000     False         0.195   0.143  ...   -17.805     1
# 18401       123666      True         0.521   0.297  ...    -7.022     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 18826       0.0291        0.0475           0.00000     0.209   0.8550
# 18526       0.0292        0.4980           0.00000     0.100   0.2560
# 18606       0.0298        0.8890           0.00025     0.104   0.2170
# 18524       0.0299        0.8010           0.17300     0.135   0.9100
# 18379       0.0300        0.6780           0.00000     0.133   0.4060
# 18446       0.0312        0.7850           0.00000     0.110   0.5010
# 18651       0.0325        0.8660           0.00000     0.107   0.3990
# 18935       0.0326        0.8860           0.00000     0.685   0.1880
# 18895       0.0346        0.9470           0.00228     0.348   0.0739
# 18401       0.0351        0.7320           0.00000     0.273   0.5170
#
#          tempo  time_signature  track_genre
# 18826  130.758               4       comedy
# 18526  114.717               4       comedy
# 18606  138.812               4       comedy
# 18524  127.129               4       comedy
# 18379  109.854               4       comedy
# 18446   89.530               4       comedy
# 18651  139.810               4       comedy
# 18935   80.065               1       comedy
# 18895   83.077               3       comedy
# 18401  118.681               4       comedy
#
# [10 rows x 21 columns]

# %% [markdown]
# We see that there are in fact some comedy songs that aren't sets. What this tells us is that for the comedy genre at least, speechiness is accurate and is not making mistakes by having comedy songs have low speechiness values. These songs accurately are comedy and have low speechiness values. This means that as a next step, we can probably find an acceptible max for speechiness and filter out all entries above that to remove podcast type entries.
#
# The dataest description on huggingface says that most songs above 0.66 likely aren't music, and are mostly talking, so I want to test this and see if this is true. We want to be able to remove entries that are mostly just talking if possible, so need to find good threshold to do this

# %%
filtered_com_speechiness = raw_data[raw_data['speechiness'] > 0.70]
filtered_com_peechiness = filtered_com_speechiness[filtered_com_speechiness['track_genre'] == 'comedy']
filtered_com_peechiness.nsmallest(10, "speechiness")
# Out:
#        Unnamed: 0                track_id  \
# 18846       18846  1NshHftLkdJcrMnCNqQf3U
# 18848       18848  1JGFhhbcEDikq0xxuAI0Mk
# 18508       18508  2iEc9ZUjvNz2UIbhjhD6B2
# 18609       18609  57x3MBUs9IE0vlZVDtrYax
# 18954       18954  5oB1UnrgyBPQLtkVWsDwI7
# 18449       18449  0WVGfCs97aWDvJGBPMFMI0
# 18983       18983  4BB3ZRYYwRlBzNj6WUVrUj
# 18423       18423  6aOzlhzJ5BemEkB9TXhNKo
# 18945       18945  4wWtnRpttsyMaJBVV9ZsR7
# 18217       18217  32Q994Bms8PgeoOBL3KViD
#
#                                             artists  \
# 18846  Hva Snakker Du Om?;Anders Matthesen;Bossy Bo
# 18848                              Kathleen Madigan
# 18508                                    Todd Glass
# 18609                                  Tracy Morgan
# 18954                               Clinton Jackson
# 18449                              Kathleen Madigan
# 18983                                    Louis Katz
# 18423                                  D.L. Hughley
# 18945                              Kathleen Madigan
# 18217                               Stuart Thompson
#
#                           album_name  \
# 18846     Den Ka' Byttes V:O:L:01:00
# 18848                Bothering Jesus
# 18508   Todd Glass Talks About Stuff
# 18609                      Bona Fide
# 18954       Do You See the Ducks Now
# 18449                Bothering Jesus
# 18983      If These Balls Could Talk
# 18423  Notes from the G.E.D. Section
# 18945                Bothering Jesus
# 18217                      Dandy Man
#
#                                               track_name  popularity  \
# 18846  Matros I Skumsprøjt Med Stormvejr og Stiv Kuli...          23
# 18848                                 Drinking & Ireland          21
# 18508           Health Department D's and Dinner Parties          22
# 18609                                           Brooklyn          22
# 18954                                   The Make-up Girl          19
# 18449                           Car Crash vs Plane Crash          23
# 18983                                    Weird Sex Moves          20
# 18423                       What I Learned from the News          22
# 18945                                Last Call from Jail          21
# 18217                                          Gun Range          25
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 18846        35293     False         0.698   0.438    2   -11.355     1
# 18848       280366      True         0.472   0.855    0    -7.011     1
# 18508       336946      True         0.575   0.945    4    -2.385     1
# 18609       138930      True         0.385   0.951    6    -4.562     1
# 18954       105626     False         0.449   0.977    1    -6.057     1
# 18449       106001     False         0.543   0.828   10    -6.980     0
# 18983       104760      True         0.502   0.895   11    -4.932     1
# 18423       125520      True         0.572   0.927    5    -5.428     1
# 18945       194510     False         0.469   0.912    6    -7.161     0
# 18217       160257      True         0.553   0.867    2   -10.140     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 18846        0.705         0.698          0.000000     0.444    0.691
# 18848        0.709         0.787          0.000000     0.931    0.381
# 18508        0.712         0.839          0.000000     0.752    0.600
# 18609        0.714         0.489          0.000000     0.969    0.106
# 18954        0.719         0.791          0.000000     0.427    0.177
# 18449        0.731         0.816          0.000000     0.748    0.691
# 18983        0.731         0.884          0.000000     0.940    0.556
# 18423        0.732         0.780          0.000000     0.911    0.583
# 18945        0.733         0.779          0.000000     0.860    0.309
# 18217        0.734         0.895          0.000003     0.600    0.866
#
#          tempo  time_signature track_genre
# 18846  139.707               3      comedy
# 18848  123.001               3      comedy
# 18508  115.992               4      comedy
# 18609  178.790               4      comedy
# 18954  119.938               1      comedy
# 18449  130.355               4      comedy
# 18983  122.856               3      comedy
# 18423   93.277               3      comedy
# 18945  135.928               3      comedy
# 18217   92.780               1      comedy

# %% [markdown]
# Let's use .70 as a threshold. The lowest songs here are all talk shows or stand up comedy routines, so we can be pretty confident we won't accidentally remove any actual music tracks with this treshold. Some tlak shows or comedies may slip in under this, but per the datasets usage guidelines, we can assume this number shouldn't be too large such that it will mess with our dataset

# %% [markdown]
# Now lets check duration. Outliers should be pretty easy to remove, as few songs are extremley long or extremely short

# %%
cleaned_data.nsmallest(20, "duration_ms")
# Out:
#                                                   artists  \
# 59310                                          Leila Bela
# 59812                                          Leila Bela
# 59775                      Leila Bela;Leila's Opera Class
# 16856              Wolfgang Amadeus Mozart;Ingrid Haebler
# 16288                    Robert Schumann;Pavel Nersessian
# 39233                    Robert Schumann;Pavel Nersessian
# 59306                                          Leila Bela
# 59609                                          Leila Bela
# 11398                    Benjamin Britten;Steven Isserlis
# 16292                    Robert Schumann;Pavel Nersessian
# 39236                    Robert Schumann;Pavel Nersessian
# 101159  Traditional;Cappella Musicale di Santa Maria i...
# 66925                                   Dora The Explorer
# 59434   Alireza Mashayekhi;Ata Ebtekar;The Iranian Orc...
# 59458                                          Leila Bela
# 59711                                          Leila Bela
# 26672                                  Alan Menken;Disney
# 98764                                  Alan Menken;Disney
# 66653                                   Dora The Explorer
# 14513                                             WowKidz
#
#                                                album_name  \
# 59310                                         Angra Manyu
# 59812                                         Angra Manyu
# 59775                                         Angra Manyu
# 16856                  Mozart: The Complete Piano Sonatas
# 16288   Schumann, Poulenc & Others: Piano Works (Live ...
# 39233   Schumann, Poulenc & Others: Piano Works (Live ...
# 59306                                         Angra Manyu
# 59609                                         Angra Manyu
# 11398                          October Classical Playlist
# 16292   Schumann, Poulenc & Others: Piano Works (Live ...
# 39236   Schumann, Poulenc & Others: Piano Works (Live ...
# 101159       Giovannini: Messa a Quattro Breve Concertata
# 66925                                   Dora The Explorer
# 59434                                       Ornamentalism
# 59458                                         Angra Manyu
# 59711                                         Angra Manyu
# 26672   A Pequena Sereia (Trilha Sonora Original em Po...
# 98764   A Pequena Sereia (Trilha Sonora Original em Po...
# 66653                                   Dora The Explorer
# 14513                         50 Top Hindi Nursery Rhymes
# 26672        0.0843        0.7960           0.00751    0.0634   0.5640
# 98764        0.0843        0.7960           0.00751    0.0634   0.5640
# 66653        0.0521        0.8390           0.00000    0.1760   0.8020
# 14513        0.0416        0.3260           0.00000    0.2060   0.9680
#
#           tempo  time_signature track_genre
# 59310     0.000               0     iranian
# 59812     0.000               0     iranian
# 59775   184.051               3     iranian
# 16856    84.375               4   classical
# 16288    89.032               1   classical
# 39233    89.032               1      german
# 59306   172.897               4     iranian
# 59609   135.107               4     iranian
# 11398    77.266               5     british
# 16292   116.093               4   classical
# 39236   116.093               4      german
# 101159   95.684               3       sleep
# 66925   109.974               4        kids
# 59434    96.548               4     iranian
# 59458   100.765               4     iranian
# 59711   119.207               5     iranian
# 26672   119.539               4      disney
# 98764   119.539               4  show-tunes
# 66653   107.881               4        kids
# 14513   104.965               4    children

# %% [markdown]
# Longest songs are dj mixes, which I guess is okay to keep. Can't see why that would warrant getting axed. There also seemt to be very few songs that are short that aren't actually songs, so I guess it's okay for them too
#
# Another I want to check for outliers is loudness. If a track is just silent, it probably shouldn't be included.

# %%
cleaned_data.nsmallest(50, "loudness")
# Out:
#                                                   artists  \
# 101888                           White Noise Sleep Sounds
# 101538                           White Noise Sleep Sounds
# 101722                                    Atmosphere Asmr
# 101360  White Noise for Babies;Crickets;Baby Sleep Sounds
# 79719                                        Lazar Berman
# 101972  Binaural Beats;White Noise Babies;Binaural Bea...
# 101968  Relaxing Music Therapy;4D Nature Recordings;Cr...
# 101476                              Wave Sounds For Sleep
# 79591                                        Brian Lyndon
# 101397      White Noise Babies;White Noise For Baby Sleep
# 101443                                 White Noise Babies
# 101447       White Noise Sleep Sounds;Sleep Sound Library
# 113520                                    Sonidos De Aves
# 101540                             Baby Sleep White Noise
# 101631          White Noise Babies;White Noise for Babies
# 101672        Vacuum Cleaner White Noise;Baby Sweet Dream
# 101688       White Noise Sleep Sounds;Sleep Sound Library
# 101939                                 White Noise Babies
# 101499                                           Granular
# 39750                                         Hans Zimmer
# 4042                                            Brian Eno
# 101352                                           nite sky
# 16090               Johann Sebastian Bach;Pietro De Maria
# 39086               Johann Sebastian Bach;Pietro De Maria
# 113618                               Mc_team;Sonic Whales
# 16061                 Ludwig van Beethoven;Murray Perahia
# 16130                 Ludwig van Beethoven;Murray Perahia
# 39146                 Ludwig van Beethoven;Murray Perahia
# 101479                                         Fan Sounds
# 101984        Vacuum Cleaner White Noise;Baby Sweet Dream
# 4391                                     Ludovico Einaudi
# 4952                                     Ludovico Einaudi
# 113467  Ruido Blanco Hart;Musica para Bebes;Canciones ...
# 101451  Study Music & Sounds;Study Alpha Waves;Binaura...
# 4394                                     Ludovico Einaudi
# 26355                                        Andy Tallent
# 101240       White Noise Sleep Sounds;Sleep Sound Library
# 76547   Giuseppe Verdi;Riccardo Muti;New Philharmonia ...
# 4432                                          Max Richter
# 113680  Ruido Blanco Hart;Musica para Bebes;Canciones ...
# 4246                                     Ludovico Einaudi
# 4311                                     Ludovico Einaudi
# 101957                                 Lluvia para Dormir
# 4097                       Philip Glass;Víkingur Ólafsson
# 16343                      Philip Glass;Víkingur Ólafsson
# 16746   Wolfgang Amadeus Mozart;English Baroque Solois...
# 16946   Wolfgang Amadeus Mozart;English Baroque Solois...
# 76253       Léo Delibes;Slovak Philharmonic;Ondrej Lenard
# 101785  Crickets - Tinnitus Sleep Solution;Relaxing Mu...
# 101200  Study Music & Sounds;Study Alpha Waves;Binaura...
#
#                                                album_name  \
# 101888                               Soothing White Noise
# 101538                               Soothing White Noise
# 101722        Fan Sounds & White Noise 2 (Deluxe Edition)
# 101360                                     Cricket Sounds
# 79719                               Inedito (Unpublished)
# 101972                               Airconditioner Noise
# 101968                          Night Crickets for Babies
# 101476                         Wave Sounds For Baby Sleep
# 79591                                        Wake with me
# 101397                               Loopable White Noise
# 101443                Loopable White Noise For Baby Sleep
# 101447                  Loopable White Noise Sleep Sounds
# 113520                                    Sonidos de Aves
# 101540                      Relaxing Loopable White Noise
# 101631                               Loopable White Noise
# 101672                           Soothing Sleeping Sounds
# 101688                  Loopable White Noise Sleep Sounds
# 101939                Loopable White Noise For Baby Sleep
# 101499                                             Unison
# 39750   Interstellar (Original Motion Picture Soundtra...
# 4042                                             ZEN 2022
# 101352                                        sierra star
# 16090                       Clásica para los niños de hoy
# 39086                       Clásica para los niños de hoy
# 113618                 888 Hz Abundancia y la Prosperidad
# 16061                       Clásica para los niños de hoy
# 16130                       Clásica para los niños de hoy
# 39146                       Clásica para los niños de hoy
# 101479                    Gentle Box Fan Breeze For Sleep
# 101984                           Soothing Sleeping Sounds
# 4391                                           Underwater
# 4952                                                Atoms
# 113467  Ruido Blanco De Ondas Para Bebés Durmiendo Vol. 1
# 101451  Study: Binaural Beats Alpha Waves Music For Re...
# 4394                                           Underwater
# 26355                                       You Are There
# 101240                  Loopable White Noise Sleep Sounds
# 76547                                         Verdi: Aida
# 4432                                                Sleep
# 113680  Ruido Blanco De Ondas Para Bebés Durmiendo Vol. 1
# 4246                                           Underwater
# 4311                                        Natural Light
# 101957  Lluvia Tranquila: Sonidos de Lluvia en el Prom...
# 4097                                    Classical Running
# 16343                                   Classical Running
# 16746                           Mozart - All Day Classics
# 16946                           Mozart - All Day Classics
# 76253                      Delibes: Best of French Ballet
# 101785                           Night Cricket for Babies
# 101200  Study: Binaural Beats Alpha Waves Music For Re...
#
#                                                track_name  popularity  \
# 101888       Soothing White Noise - Loopable With No Fade          32
# 101538                White Noise - Loopable With No Fade          37
# 101722                     Ceiling Fan Sound on Low Power          34
# 101360            Cricket Sound 4 - Loopable With No Fade          54
# 79719             Chaconne in sol maggiore : Variazione 9          58
# 101972                       Nap in the Afternoon Box Fan          32
# 101968                                     Loopable Woods          32
# 101476                Sleep Sound For Babies - Underwater          36
# 79591                                        Wake with me          60
# 101397  Clean White Noise - Loopable With No Fade - Wh...          39
# 101443          Clean White Noise - Loopable Without Fade          38
# 101447          Clean White Noise - Loopable With No Fade          38
# 113520                                    Sonidos de Aves          26
# 101540                    Box Fan - Loopable With No Fade          36
# 101631  Air Conditioner - Loopable With No Fade (feat....          34
# 101672  Air Conditioner - Loopable With No Fade - Baby...          34
# 101688            Air Conditioner - Loopable With No Fade          34
# 101939            Air Conditioner - Loopable Without Fade          32
# 101499                      White Noise - Hi Res 178,9 hz          37
# 39750                                   Message from Home          53
# 4042                            Signals - Remastered 2005           0
# 101352                                        sierra star          63
# 16090   The Well-Tempered Clavier, Book I, BWV 846-869...           0
# 39086   The Well-Tempered Clavier, Book I, BWV 846-869...           0
# 113618                             888 Hz Ondas Cuánticas          25
# 16061   Piano Sonata No. 14 in C-Sharp Minor, Op. 27 N...           0
# 16130   Piano Sonata No. 14 in C-Sharp Minor, Op. 27 N...           0
# 39146   Piano Sonata No. 14 in C-Sharp Minor, Op. 27 N...           0
# 101479                    Gentle Box Fan Breeze For Sleep          37
# 101984  Clean White Noise - Loopable With No Fade - Ba...          31
# 4391                                                Atoms          58
# 4952                                                Atoms          49
# 113467                              Ruido Blanco De Costa          27
# 101451                                         Deep Focus          44
# 4394                                            Swordfish          58
# 26355                                       You Are There          24
# 101240                White Noise - Loopable With No Fade          47
# 76547   Verdi: Aida, Act 1: "Danza sacra delle sacerdo...          23
# 4432    Dream 1 (before the wind blows it all away) - ...          55
# 113680                             Grandes Olas Rompiendo          24
# 4246                                        Natural Light          62
# 4311                                        Natural Light          62
# 101957                                       Niebla Suave          31
# 4097                                  Glassworks: Opening           0
# 16343                                 Glassworks: Opening           0
# 16746   Idomeneo, re di Creta, K.366 / Act 3: Marcia -...           7
# 16946   Idomeneo, re di Creta, K.366 / Act 3: Marcia -...           7
# 76253                                   Sylvia: Pizzicato          53
# 101785                                      Loopable Owls          33
# 101200                                        Study Music          46
#
#         duration_ms  explicit  danceability    energy  key  loudness  mode  \
# 101888        65248     False        0.0000  0.000687   10   -49.531     0
# 101538        74217     False        0.0000  0.003320   10   -49.307     0
# 101722       120000     False        0.1620  0.004830    6   -46.591     0
# 101360        71000     False        0.4610  0.003250   10   -46.251     0
# 79719         63840     False        0.3870  0.001810    7   -43.957     0
# 101972        60000     False        0.1880  0.414000    1   -43.943     0
# 101968        99778     False        0.3810  0.086000    9   -43.714     1
# 101476       139661     False        0.2440  0.145000   10   -43.504     0
# 79591        135647     False        0.2770  0.001760    0   -43.303     1
# 101397        67682     False        0.0000  0.000020   10   -43.046     1
# 101443        67682     False        0.0000  0.000020   10   -43.046     1
# 101447        67682     False        0.0000  0.000020   10   -43.046     1
# 113520        64470     False        0.4110  0.017300    8   -43.043     1
# 101540        78600     False        0.0000  0.000257    5   -42.995     0
# 101631        77482     False        0.0000  0.000638    1   -42.864     1
# 101672        77482     False        0.0000  0.000638    1   -42.864     1
# 101688        77482     False        0.0000  0.000638    1   -42.864     1
# 101939        77482     False        0.0000  0.000638    1   -42.864     1
# 101499       139354     False        0.1750  0.076500    5   -42.631     0
# 39750        100877     False        0.2320  0.001080    7   -42.044     1
# 4042         166560     False        0.1920  0.011900    6   -41.808     1
# 16090        0.0413      0.991000          0.941000    0.0643  0.08390
# 39086        0.0413      0.991000          0.941000    0.0643  0.08390
# 113618       0.0408      0.992000          0.925000    0.1130  0.05690
# 16061        0.0434      0.995000          0.945000    0.1130  0.09730
# 16130        0.0434      0.995000          0.945000    0.1130  0.09730
# 39146        0.0434      0.995000          0.945000    0.1130  0.09730
# 101479       0.0000      0.731000          0.864000    0.3890  0.00000
# 101984       0.0000      0.971000          0.717000    0.1050  0.00000
# 4391         0.0657      0.995000          0.954000    0.1120  0.15900
# 4952         0.0657      0.995000          0.954000    0.1120  0.15900
# 113467       0.0616      0.987000          0.973000    0.1080  0.03130
# 101451       0.0442      0.950000          0.853000    0.1140  0.03500
# 4394         0.0447      0.995000          0.921000    0.1050  0.41600
# 26355        0.0469      0.989000          0.869000    0.0874  0.05550
# 101240       0.0000      0.994000          0.072700    0.1070  0.00000
# 76547        0.0384      0.986000          0.447000    0.0928  0.23900
# 4432         0.0487      0.995000          0.968000    0.0998  0.08660
# 113680       0.1010      0.960000          0.972000    0.1070  0.17300
# 4246         0.0515      0.992000          0.951000    0.1390  0.19200
# 4311         0.0515      0.992000          0.951000    0.1390  0.19200
# 101957       0.0437      0.869000          0.981000    0.9640  0.00001
# 4097         0.0405      0.994000          0.915000    0.0710  0.09770
# 16343        0.0405      0.994000          0.915000    0.0710  0.09770
# 16746        0.0379      0.805000          0.000513    0.5420  0.32700
# 16946        0.0379      0.805000          0.000513    0.5420  0.32700
# 76253        0.0533      0.875000          0.078700    0.0615  0.18900
# 101785       0.0411      0.100000          0.961000    0.1670  0.03820
# 101200       0.0472      0.944000          0.849000    0.1030  0.03660
#
#           tempo  time_signature  track_genre
# 101888    0.000               0        sleep
# 101538    0.000               0        sleep
# 101722  138.768               4        sleep
# 101360  111.653               4        sleep
# 79719    98.691               4        piano
# 101972  136.862               4        sleep
# 101968  137.552               3        sleep
# 101476  138.094               4        sleep
# 79591   110.541               4        piano
# 101397    0.000               0        sleep
# 101443    0.000               0        sleep
# 101447    0.000               0        sleep
# 113520   77.255               4  world-music
# 101540    0.000               0        sleep
# 101631    0.000               0        sleep
# 101672    0.000               0        sleep
# 101688    0.000               0        sleep
# 101939    0.000               0        sleep
# 101499   72.054               3        sleep
# 39750    83.854               4       german
# 4042     69.045               1      ambient
# 101352  139.474               4        sleep
# 16090   140.353               4    classical
# 39086   140.353               4       german
# 113618  145.861               4  world-music
# 16061   166.462               3    classical
# 16130   166.462               3    classical
# 39146   166.462               3       german
# 101479    0.000               0        sleep
# 101984    0.000               0        sleep
# 4391     68.921               4      ambient
# 4952     68.921               4      ambient
# 113467  149.980               4  world-music
# 101451   70.804               4        sleep
# 4394     80.772               4      ambient
# 26355    95.453               4       disney
# 101240    0.000               0        sleep
# 76547    81.078               4        opera
# 4432     72.046               4      ambient
# 113680   85.856               4  world-music
# 4246     68.610               4      ambient
# 4311     68.610               4      ambient
# 101957   57.282               3        sleep
# 4097    213.848               3      ambient
# 16343   213.848               3    classical
# 16746    94.799               4    classical
# 16946    94.799               4    classical
# 76253   159.236               4        opera
# 101785   90.477               4        sleep
# 101200   67.932               4        sleep

# %% [markdown]
# This brings to our attention the genre "sleep." Lets see how many tracks are sleep tracks

# %%
sleep_tracks = train[train['track_genre'] == 'sleep']
sleep_tracks.count()
# Out:
# Unnamed: 0          592
# track_id            592
# artists             592
# album_name          592
# track_name          592
# popularity          592
# duration_ms         592
# explicit            592
# danceability        592
# energy              592
# key                 592
# loudness            592
# mode                592
# speechiness         592
# acousticness        592
# instrumentalness    592
# liveness            592
# valence             592
# tempo               592
# time_signature      592
# track_genre         592
# dtype: int64

# %% [markdown]
# After some analysis I see that there are about 100 songs classified under the sleep genre. A LOT of them are white noise tracks, some are not. I really think that given the relative size of the dataset, and the amount of data in the sleep genre, we can just remove them all and not worry terribly about adverse effects. I will add the code that removes the sleep genre to the pre-processing section.

# %% [markdown]
# Based on what we found earlier, we know some genres are plainly obvious by name that thye are problematic. Let's check all the unique genres to see if anything else stands out.

# %%
train["track_genre"].unique()
# Out:
# array(['soul', 'romance', 'metalcore', 'j-rock', 'rockabilly', 'disney',
#        'samba', 'alt-rock', 'show-tunes', 'folk', 'singer-songwriter',
#        'power-pop', 'guitar', 'kids', 'minimal-techno', 'malay',
#        'indie-pop', 'heavy-metal', 'emo', 'new-age', 'grindcore',
#        'spanish', 'hardstyle', 'mpb', 'deep-house', 'british', 'salsa',
#        'edm', 'pop', 'honky-tonk', 'forro', 'iranian', 'world-music',
#        'r-n-b', 'gospel', 'dub', 'indie', 'opera', 'house', 'indian',
#        'ambient', 'comedy', 'hardcore', 'trance', 'punk-rock', 'garage',
#        'drum-and-bass', 'alternative', 'country', 'goth', 'electronic',
#        'sleep', 'songwriter', 'detroit-techno', 'industrial', 'dubstep',
#        'chicago-house', 'party', 'french', 'metal', 'electro', 'hip-hop',
#        'tango', 'funk', 'groove', 'hard-rock', 'pop-film', 'rock-n-roll',
#        'psych-rock', 'rock', 'club', 'anime', 'punk', 'reggae',
#        'afrobeat', 'dancehall', 'disco', 'dance', 'bluegrass', 'swedish',
#        'children', 'happy', 'german', 'mandopop', 'reggaeton',
#        'death-metal', 'black-metal', 'grunge', 'j-dance', 'turkish',
#        'cantopop', 'brazil', 'breakbeat', 'latino', 'k-pop', 'ska',
#        'piano', 'progressive-house', 'idm', 'blues', 'classical', 'jazz',
#        'study', 'sad', 'acoustic', 'synth-pop', 'latin', 'sertanejo',
#        'trip-hop', 'j-idol', 'j-pop', 'pagode', 'chill', 'techno'],
#       dtype=object)

# %% [markdown]
# Looks all good. Now lets check some other columns for potential issues or malformed data.

# %%
checking_mode = train[~train['mode'].isin([0,1])]
checking_mode.shape
# Out:
# (0, 21)

# %% [markdown]
# No rows that have a mode that isn't 0 or 1, so valid. Nothing to remove here. Next we check key. We know that if a key is -1, no key was detected. So lets checl the nsmallest key to see if -1 was detected.

# %%
train.nsmallest(20, "key")
# Out:
#         Unnamed: 0                track_id  \
# 45214        45214  6g4oYXbiCRAU8iPIAPR5Rm
# 113515  109.707               4        world-music
# 95087   108.885               4              salsa
# 55315   179.978               4             indian
# 12958   153.020               3           cantopop
# 100778  116.012               4                ska
# 90422   134.019               4        rock-n-roll
# 110917  125.002               4             trance
# 4528    137.764               5            ambient

# %% [markdown]
# No undetected keys, no changes necessary.

# %% [markdown]
#  Lets check time signature. The dataset says that time signatures should range from 3-7, indicating 3/4 - 7/4 time signitures respectively. Lets check how many unique values there are.

# %%
train["time_signature"].unique()
# Out:
# array([4, 3, 5, 1, 0])

# %%
(train["time_signature"] < 3).sum()
# Out:
# np.int64(705)

# %% [markdown]
# Interestingly, the time signatures only go up to 4 and never to seven. This number of unique time signatures is the same amount between 3-7, but never exceed 4, so I wonder if these values are used such that 3 + time_signature represents the actual time signature. i.e. if the row has itme signature 0, its true time signature is 3 or 3/4. To check this, I can see the most popular song that is time signature 0, and google online it's time signature. If I see a trend here indicating that this is the case, we don't have to remove any songs. If This is not the case, we will have to remove any song with a time signature below 3.

# %%
popular_zero_time = train[train['time_signature'] == 1]
popular_nosleep_zero_time = popular_zero_time[popular_zero_time['track_genre'] != "sleep"]
popular_nosleep_zero_time.nlargest(30, "popularity")
# Out:
#         Unnamed: 0                track_id  \
# 81954        81954  6jRq8gaZhMUyy5RclRPcAf
# 57057        57057  6N22FZs2ZhPBYi3b9XPajV
# 56010        56010  6N22FZs2ZhPBYi3b9XPajV
# 31012        31012  6jRq8gaZhMUyy5RclRPcAf
# 84109        84109  0vFOzaXqZHahrZp6enQwQb
# 4035          4035  3weNRklVDqb4Rr5MhKBR3D
# 16312        16312  3weNRklVDqb4Rr5MhKBR3D
# 47413        47413  6s0NHplywwr1IjnQpUpWJk
# 8421          8421  6s0NHplywwr1IjnQpUpWJk
# 51097        51097  6sPW145Y3LSXd4p1LjBOcS
# 103810      103810  10ImcQk9tihY1EKMDIbvXJ
# 44247        44247  4A065x9kJt955eGVqf813g
# 51096        51096  6XmBh5HSdVzEAaqzEftL9t
# 81478        81478  6XmBh5HSdVzEAaqzEftL9t
# 38373        38373  3CkjLJYnnyOtGk4Jx4iYS4
# 34922        34922  3ccDb4UqLC54IoFJ8LmFoy
# 84515        84515  3CkjLJYnnyOtGk4Jx4iYS4
# 80214        80214  73y649QhnXdcm6fRdvfraO
# 16574        16574  3Dgmyz32dxvtxvUTPS0CUI
# 4166          4166  1ZC21hJb2GASRkaoZvUcCS
# 79206        79206  5t9WS1mp1WGOqz6lJut8za
# 102210      102210  4tI1u9uQXYLnswRzcysxDo
# 34585        34585  7BVwi9cIzSc6tpyxsp47vJ
# 99212        99212  4tI1u9uQXYLnswRzcysxDo
# 111013      111013  7x8pIrhMu9FCmqqHNyuH0P
# 106453      106453  1OEN5wnzICsfdDOGbwaAdb
# 79279        79279  4QRkCwqwHFaZ7xeoR9CHL6
# 80353        80353  14uXhHNINQqjl2hngD21s9
# 51337        51337  2TCrYxhFs1CTFupauXzbIm
# 79373        79373  47u0q4Z7iALJXli6pkcnvA
#
#                                       artists  \
# 81954                               blackbear
# 57057                                Labrinth
# 56010                                Labrinth
# 31012                               blackbear
# 84109                              Pink Floyd
# 4035                         Ludovico Einaudi
# 16312                        Ludovico Einaudi
# 47413       George Thorogood & The Destroyers
# 8421        George Thorogood & The Destroyers
# 51097                     Anirudh Ravichander
# 103810                                  Adele
# 44247                         Alice In Chains
# 51096   Stephen Zechariah;Srinisha Jayaseelan
# 81478   Stephen Zechariah;Srinisha Jayaseelan
# 38373                              Wolfmother
# 34922                            Garrett Kato
# 84515                              Wolfmother
# 80214                    Ajay-Atul;Sonu Nigam
# 16574         Antonio Vivaldi;Florian Christl
# 4166                              Joep Beving
# 79206                                Davignon
# 102210                                  Zevia
# 34585                               Vance Joy
# 99212                                   Zevia
# 111013                              FKA twigs
# 106453                                    VAX
# 79279                                   Keane
# 80353                              Adnan Sami
# 51337                        Sidhu Moose Wala
# 79373                       Cassandra Nestico
#
#                                                album_name  \
# 81954                            everything means nothing
# 57057       Euphoria (Original Score from the HBO Series)
# 56010       Euphoria (Original Score from the HBO Series)
# 31012                            everything means nothing
# 84109                           The Dark Side of the Moon
# 4035                                          Una Mattina
# 16312                                         Una Mattina
# 47413                                     BAD TO THE BONE
# 8421                                      BAD TO THE BONE
# 51097                                               David
# 103810                                                 30
# 44247                                Dirt (2022 Remaster)
# 51096                                           Adi Penne
# 81478                                           Adi Penne
# 38373                                          Wolfmother
# 34922                                      I'll Be Around
# 84515                                          Wolfmother
# 80214      Agneepath (Original Motion Picture Soundtrack)
# 16574   Vivaldi Variation (Arr. for Piano from Concert...
# 4166                                              Trilogy
# 79206                                           Dualities
# 102210                                 we're all sad here
# 34585                                Dream Your Life Away
# 99212                                  we're all sad here
# 111013                                          MAGDALENE
# 106453                                            Riptide
# 79279                                         Strangeland
# 80353                                         Tera Chehra
# 51337                                           Moosetape
# 79373                                            Mystique
#
#                                                track_name  popularity  \
# 81954                                     hot girl bummer          80
# 57057                            Still Don't Know My Name          80
# 56010                            Still Don't Know My Name          80
# 31012                                     hot girl bummer          80
# 84109                                               Money          73
# 4035                                       Nuvole Bianche          73
# 16312                                      Nuvole Bianche          73
# 47413                                     Bad To The Bone          71
# 8421                                      Bad To The Bone          71
# 51097                                       Kanave Kanave          70
# 103810                                        To Be Loved          70
# 44247                          Them Bones (2022 Remaster)          69
# 51096                                           Adi Penne          68
# 81478                                           Adi Penne          68
# 38373                                               Woman          65
# 34922                                      I'll Be Around          65
# 84515                                               Woman          65
# 80214                                Abhi Mujh Mein Kahin          65
# 16574   Vivaldi Variation (Arr. for Piano from Concert...          65
# 4166                                                  Ala          64
# 79206                                           Dualities          64
# 102210                                 life, i'm over you          64
# 34585                                        Mess Is Mine          64
# 99212                                  life, i'm over you          64
# 111013                                         cellophane          63
# 106453                                            Riptide          63
# 79279                                Sovereign Light Café          62
# 80353                                         Tera Chehra          62
# 51337                                              Regret          62
# 79373                                            Mystique          61
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
#
# 111013       0.0432      0.871000          0.000136    0.0899   0.2290
# 106453       0.0417      0.795000          0.000000    0.2660   0.2570
# 79279        0.0302      0.013000          0.000000    0.1560   0.5090
# 80353        0.0331      0.523000          0.002100    0.1040   0.4880
# 51337        0.0577      0.467000          0.000000    0.0944   0.4660
# 79373        0.0395      0.983000          0.942000    0.1080   0.1370
#
#           tempo  time_signature        track_genre
# 81954   129.992               1                pop
# 57057    89.643               1              indie
# 56010    89.643               1          indie-pop
# 31012   129.992               1            electro
# 84109   126.256               1         psych-rock
# 4035    132.614               1            ambient
# 16312   132.614               1          classical
# 47413   149.231               1          hard-rock
# 8421    149.231               1              blues
# 51097    95.015               1            hip-hop
# 103810  170.425               1               soul
# 44247   165.014               1             grunge
# 51096   107.978               1            hip-hop
# 81478   107.978               1                pop
# 38373   112.886               1             garage
# 34922    79.024               1               folk
# 84515   112.886               1         psych-rock
# 80214   129.959               1           pop-film
# 16574    78.809               1          classical
# 4166     79.487               1            ambient
# 79206   127.897               1              piano
# 102210   78.677               1         songwriter
# 34585   108.043               1               folk
# 99212    78.677               1  singer-songwriter
# 111013   98.317               1           trip-hop
# 106453   76.969               1            swedish
# 79279   122.840               1              piano
# 80353   100.000               1           pop-film
# 51337    73.416               1            hip-hop
# 79373   165.912               1              piano

# %% [markdown]
# Weirdly, a lot of these songs do in fact have valid time signatures when investigating. For example, "Hello Dolly" by Louis Armstrong has a time signature of 4/4 when verifying online, yet the dataset has that listed with time signature 4/4. Similarly Vance Joy's "Mess is Mine" has some parts as 4/4 and some parts 3/4, yet has time_signature "1". I want to see if this metric is unreliable for 4 time signature songs, because if so, we ought to just remove the entire column.

# %%
popular_three_time = train[train['time_signature'] == 4]
popular_nosleep_three_time = popular_three_time[popular_three_time['track_genre'] != "sleep"]
popular_nosleep_three_time.nlargest(20, "popularity")
# Out:
#        Unnamed: 0                track_id                     artists  \
# 20001       20001  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 81051       81051  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 51664       51664  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 88410       88410  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 89411       89411  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 81210       81210  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 67356       67356  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 20008       20008  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 67358       67358  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 68305       68305  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 88405       88405  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 89407       89407  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 89405       89405  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 68304       68304  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 67359       67359  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 81003       81003  5IgjP7X4th6nMNDh4akUHb                 Chris Brown
# 67559       67559  5Eax0qFko2dh7Rl2lYs3bx                   Bad Bunny
# 81174       81174  4h9wh7iOZ0GGn8QVp4RAOB                 OneRepublic
# 91003       91003  4h9wh7iOZ0GGn8QVp4RAOB                 OneRepublic
# 68359       68359  5Eax0qFko2dh7Rl2lYs3bx                   Bad Bunny
#
#                                               album_name  \
# 20001                          Unholy (feat. Kim Petras)
# 81051                          Unholy (feat. Kim Petras)
# 51664              Quevedo: Bzrp Music Sessions, Vol. 52
# 88410                                         La Bachata
# 89411                                         La Bachata
# 81210                                    I'm Good (Blue)
# 67356                                         La Bachata
# 20008                                    I'm Good (Blue)
# 67358                                   Un Verano Sin Ti
# 68305                                   Un Verano Sin Ti
# 88405                                   Un Verano Sin Ti
# 89407                                   Un Verano Sin Ti
# 89405                                   Un Verano Sin Ti
# 68304                                   Un Verano Sin Ti
# 67359                                   Un Verano Sin Ti
# 81003                                  Indigo (Extended)
# 67559                                   Un Verano Sin Ti
# 81174  I Ain’t Worried (Music From The Motion Picture...
# 91003  I Ain’t Worried (Music From The Motion Picture...
# 68359                                   Un Verano Sin Ti
#
#                                   track_name  popularity  duration_ms  \
# 20001              Unholy (feat. Kim Petras)         100       156943
# 81051              Unholy (feat. Kim Petras)         100       156943
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52          99       198937
# 88410                             La Bachata          98       162637
# 89411                             La Bachata          98       162637
# 81210                        I'm Good (Blue)          98       175238
# 67356                             La Bachata          98       162637
# 20008                        I'm Good (Blue)          98       175238
# 67358                        Me Porto Bonito          97       178567
# 68305                        Me Porto Bonito          97       178567
# 88405                        Me Porto Bonito          97       178567
# 89407                        Me Porto Bonito          97       178567
# 89405                       Tití Me Preguntó          97       243716
# 68304                       Tití Me Preguntó          97       243716
# 67359                       Tití Me Preguntó          97       243716
# 81003                    Under The Influence          96       184613
# 67559                                 Efecto          96       213061
# 81174                        I Ain't Worried          96       148485
# 91003                        I Ain't Worried          96       148485
# 68359                                 Efecto          96       213061
#
#        explicit  danceability  energy  key  loudness  mode  speechiness  \
# 20001     False         0.714   0.472    2    -7.375     1       0.0864
# 81051     False         0.714   0.472    2    -7.375     1       0.0864
# 51664     False         0.621   0.782    2    -5.548     1       0.0440
# 88410     False         0.835   0.679    7    -5.329     0       0.0364
# 89411     False         0.835   0.679    7    -5.329     0       0.0364
# 81210      True         0.561   0.965    7    -3.673     0       0.0343
# 67356     False         0.835   0.679    7    -5.329     0       0.0364
# 20008      True         0.561   0.965    7    -3.673     0       0.0343
# 67358      True         0.911   0.712    1    -5.105     0       0.0817
# 68305      True         0.911   0.712    1    -5.105     0       0.0817
# 88405      True         0.911   0.712    1    -5.105     0       0.0817
# 89407      True         0.911   0.712    1    -5.105     0       0.0817
# 89405     False         0.650   0.715    5    -5.198     0       0.2530
# 68304     False         0.650   0.715    5    -5.198     0       0.2530
# 67359     False         0.650   0.715    5    -5.198     0       0.2530
# 81003      True         0.733   0.690    9    -5.529     0       0.0427
# 67559     False         0.801   0.475    7    -8.797     0       0.0516
# 81174     False         0.704   0.797    0    -5.927     1       0.0475
# 91003     False         0.704   0.797    0    -5.927     1       0.0475
# 68359     False         0.801   0.475    7    -8.797     0       0.0516
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 20001       0.01300          0.000005    0.2660    0.238  131.121
# 81051       0.01300          0.000005    0.2660    0.238  131.121
# 51664       0.01250          0.033000    0.2300    0.550  128.033
# 88410       0.58300          0.000002    0.2180    0.850  124.980
# 89411       0.58300          0.000002    0.2180    0.850  124.980
# 81210       0.00383          0.000007    0.3710    0.304  128.040
# 67356       0.58300          0.000002    0.2180    0.850  124.980
# 20008       0.00383          0.000007    0.3710    0.304  128.040
# 67358       0.09010          0.000027    0.0933    0.425   92.005
# 68305       0.09010          0.000027    0.0933    0.425   92.005
# 88405       0.09010          0.000027    0.0933    0.425   92.005
# 89407       0.09010          0.000027    0.0933    0.425   92.005
# 89405       0.09930          0.000291    0.1260    0.187  106.672
# 68304       0.09930          0.000291    0.1260    0.187  106.672
# 67359       0.09930          0.000291    0.1260    0.187  106.672
# 81003       0.06350          0.000001    0.1050    0.310  116.992
# 67559       0.14100          0.000017    0.0639    0.234   98.047
# 81174       0.08260          0.000745    0.0546    0.825  139.994
# 91003       0.08260          0.000745    0.0546    0.825  139.994
# 68359       0.14100          0.000017    0.0639    0.234   98.047
#
#        time_signature track_genre
# 20001               4       dance
# 81051               4         pop
# 51664               4     hip-hop
# 88410               4      reggae
# 89411               4   reggaeton
# 81210               4         pop
# 67356               4       latin
# 20008               4       dance
# 67358               4       latin
# 68305               4      latino
# 88405               4      reggae
# 89407               4   reggaeton
# 89405               4   reggaeton
# 68304               4      latino
# 67359               4       latin
# 81003               4         pop
# 67559               4       latin
# 81174               4         pop
# 91003               4        rock
# 68359               4      latino

# %% [markdown]
# Honestly, cross verifying many of the time signatures with actual song time signatures found from online, the time signature detection seems to not be very accurate. We should drop the whole column.
#
# While performing this, I realized many songs with multiple genres appear as multiple rows with the exact same stats but different genre. This could skew results. I want to see how many of the rows in our datasets consist of duplicates, and if this is a serious issue we must consider.

# %%
train.shape
# Out:
# (68400, 21)

# %%
train["track_id"].nunique()
# Out:
# 58424

# %% [markdown]
# About 10k entries are duplicates. We should do something here, but we haven't reached a consensus on that yet so we will do that after that consensus is reached.
#
#  ***DO NOT IGNORE, COME BACK TO THIS LATER AND CHANGE***

# %% [markdown]
# Lets check any tempo outliers

# %%
low_tempo = train[train["tempo"] == 0]
low_tempo_nosleep = low_tempo[low_tempo["track_genre"] != "sleep"]
low_tempo_nosleep.shape
# Out:
# (11, 21)

# %%
low_tempo_nosleep.nlargest(20, "popularity")
# Out:
#         Unnamed: 0                track_id  \
# 4131          4131  59gg6zQhSKGVnkT3hWAY3l
# 64826        64826  63kd4m3VFxcJjPVVtbVNAu
# 4379          4379  4acmzQsAeMJa5sGFSog7fu
# 76716        76716  7KHG8MHzxAv0YnLFBWY9Y1
# 113428      113428  5EYzrykQ95uOmepteDi9KT
# 45720        45720  7i5OoyPXtSrqz9jobJfG1F
# 45729        45729  0pTAEdockvKVSq1hhFqk7O
# 113856      113856  6XsYJ0dwT2hRzp0Qles78F
# 45670        45670  6B9Mgf9smWqxDjA35VD6MK
# 59473        59473  48Nt8u7kYSTwE6axtE9hJO
# 59812        59812  38Ogh3rsHba83kXx13gbKs
#
#                                                   artists  \
# 4131                                Max Richter;Lang Lang
# 64826                                     Louis Armstrong
# 4379     Dario Marianelli;Jack Liebeck;Benjamin Wallfisch
# 76716   Jean-Baptiste Lully;Mary Enid Haines;Sharla Na...
# 113428  El Ruido Blanco;Soñoliento Juan;Mantra para Do...
# 45720                                     Little Symphony
# 45729                                     Little Symphony
# 113856                                  Колыбельная-земля
# 45670                                     Little Symphony
# 59473                                          Leila Bela
# 59812                                          Leila Bela
#
#                                                album_name  \
# 4131                      Voyager - Essential Max Richter
# 64826                          Hello, Dolly! (Remastered)
# 4379       Jane Eyre - Original Motion Picture Soundtrack
# 76716                Lully: Ballet Music for the Sun King
# 113428                 Aire Acondicionado de Ruido Blanco
# 45720                                        Rialto Beach
# 45729                                        Rialto Beach
# 113856  Расслабляющие звуки - белый шум для вашего реб...
# 45670                                        Rialto Beach
# 59473                                         Angra Manyu
# 59812                                         Angra Manyu
#
#                                                track_name  popularity  \
# 4131                                        The Departure          64
# 64826                                       Hello, Dolly!          62
# 4379            The End of Childhood (feat. Jack Liebeck)          55
# 76716   Le bourgeois gentilhomme: Chaconne des Scaramo...          51
# 113428                                     Aire de verano          27
# 45720                                          Ritornello          23
# 45729                                              Amager          22
# 113856                                Пылесос (Белый шум)          22
# 45670                                           Campomoro          22
# 59473               Leaving Her Quantum Journey Behind...           0
# 59812                                                 V-4           0
#
#         duration_ms  explicit  danceability   energy  key  loudness  mode  \
# 4131         151506     False           0.0  0.03620    0   -22.519     0
# 64826        147000     False           0.0  0.40500    0    -9.935     1
# 4379          73266     False           0.0  0.04450    0   -26.440     0
# 76716         88160     False           0.0  0.01920    6   -28.821     1
# 113428       128000     False           0.0  0.18800    8   -25.837     0
# 45720        102000     False           0.0  0.00129    7   -29.445     1
# 45729        133624     False           0.0  0.00400    0   -28.326     1
# 113856       302185     False           0.0  0.22400    8   -10.224     1
# 45670        148711     False           0.0  0.00108    0   -30.204     1
# 59473         50186     False           0.0  0.03140    5   -28.194     0
# 59812         13386     False           0.0  0.22400   11   -22.196     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# 4131            0.0         0.994          0.940000    0.0958      0.0    0.0
# 64826           0.0         0.842          0.001140    0.1980      0.0    0.0
# 4379            0.0         0.972          0.972000    0.0873      0.0    0.0
# 76716           0.0         0.936          0.019700    0.1380      0.0    0.0
# 113428          0.0         0.139          0.339000    0.1220      0.0    0.0
# 45720           0.0         0.969          0.956000    0.1230      0.0    0.0
# 45729           0.0         0.970          0.959000    0.1090      0.0    0.0
# 113856          0.0         0.142          0.986000    0.4110      0.0    0.0
# 45670           0.0         0.952          0.991000    0.2420      0.0    0.0
# 59473           0.0         0.723          0.000067    0.1290      0.0    0.0
# 59812           0.0         0.970          0.000000    0.9070      0.0    0.0
#
#         time_signature  track_genre
# 4131                 0      ambient
# 64826                0         jazz
# 4379                 0      ambient
# 76716                0        opera
# 113428               0  world-music
# 45720                0       guitar
# 45729                0       guitar
# 113856               0  world-music
# 45670                0       guitar
# 59473                0      iranian
# 59812                0      iranian

# %% [markdown]
# Some songs have a tempo of 0, and investigating these, they seemt to just be songs where accurate analysis of their qualities never properly went through, given by them having 0 valence and time signature as well. We should just go ahead and drop these songs, as they are a relatively small number of entries and would be hard to reasonably impute.
#
#
#   (NOTE: we excluse sleep songs from our anlaysis of songs above because we are already removing these songs along with all sleep genre songs)

# %% [markdown]
# Now that we've selected some things to remove and done basic EDA, lets quickly check a correlation matrix to see if any specific features can be removed. We already know we want to remove artists, track_id, album_name, and track_name, because we want to judge music based on the merit of the actual song and not on popuilarity associated with any particular artist name. The goal of the model is to predict a song's popularity based on it's quality, not based on it's producer. Another row we want to remove is time_signature, as determined from above metrics

# %%
numerical_cols = train.select_dtypes(include=np.number).columns.tolist()

correlation_matrix = raw_data[numerical_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix[['popularity']].sort_values(by='popularity', ascending=False), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation with Popularity')
plt.show()

# %% [markdown]
# We see pretty low correlations all across the board, which is okay, because the anture of music and poopularity is complex and very likely isn't a simple linear relationship that would appear on a correlation matrix. This does help indicate what features may be nice to focus on when attempting to do linear regression, however. We can sort of predict linear regression won't be that great based on this correlation matrix, but we will still do regression for practice and in case anything jumps out during that process.

# %% [markdown]
# #Pre-Processing

# %% [markdown]
# Based on our EDA, we can go ahead and remove columns and outlier values from our data sets.

# %%
def clean_df(raw_df):
  cleaned_df = raw_df.dropna()
  drop_columns = ['track_id', 'album_name', 'artists', 'track_name', 'Unnamed: 0', 'time_signature']
  cleaned_df = cleaned_df.drop(columns=drop_columns)
  cleaned_df = cleaned_df[cleaned_df['track_genre'] != 'sleep']
  cleaned_df = cleaned_df[cleaned_df["tempo"] > 10]
  cleaned_df = cleaned_df[cleaned_df["speechiness"] < 90]
  cleaned_df = cleaned_df[~(
      (cleaned_df["speechiness"] > 70) &
      (cleaned_df["track_genre"] == "comedy"))
  ]
  return cleaned_df

# %%
cleaned_train = clean_df(train)
cleaned_validate = clean_df(validate)
cleaned_test = clean_df(test)

# %% [markdown]
# Now let's sanity check the shape of all our dfs to make sure nothing went wrong:

# %%
cleaned_train.shape
# Out:
# (67797, 15)

# %%
cleaned_validate.shape
# Out:
# (22580, 15)

# %%
cleaned_test.shape
# Out:
# (22603, 15)

# %% [markdown]
# All good. Our preprocessing worked, and we have slimed down the data slightly and made it more workable!

# %% [markdown]
# #Regression Analysis

# %% [markdown]
# #Logistic Regression

# %% [markdown]
# #Classification

# %% [markdown]
# #PCA and Clustering

# %% [markdown]
# #Neural Network
